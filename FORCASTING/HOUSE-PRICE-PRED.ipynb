# %% [markdown]
# LOAD DATA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("HousingPrices-Amsterdam-August-2021.csv")
df
# Out:
#      Unnamed: 0                                 Address      Zip     Price  \
# 0             1            Blasiusstraat 8 2, Amsterdam  1091 CR  685000.0
# 1             2  Kromme Leimuidenstraat 13 H, Amsterdam  1059 EL  475000.0
# 2             3              Zaaiersweg 11 A, Amsterdam  1097 SM  850000.0
# 3             4            Tenerifestraat 40, Amsterdam  1060 TH  580000.0
# 4             5              Winterjanpad 21, Amsterdam  1036 KN  720000.0
# ..          ...                                     ...      ...       ...
# 919         920                     Ringdijk, Amsterdam  1097 AE  750000.0
# 920         921         Kleine Beerstraat 31, Amsterdam  1033 CP  350000.0
# 921         922       Stuyvesantstraat 33 II, Amsterdam  1058 AK  350000.0
# 922         923   John Blankensteinstraat 51, Amsterdam  1095 MB  599000.0
# 923         924      S. F. van Ossstraat 334, Amsterdam  1068 JS  300000.0
#
#      Area  Room       Lon        Lat
# 0      64     3  4.907736  52.356157
# 1      60     3  4.850476  52.348586
# 2     109     4  4.944774  52.343782
# 3     128     6  4.789928  52.343712
# 4     138     5  4.902503  52.410538
# ..    ...   ...       ...        ...
# 919   117     1  4.927757  52.354173
# 920    72     3  4.890612  52.414587
# 921    51     3  4.856935  52.363256
# 922   113     4  4.965731  52.375268
# 923    79     4  4.810678  52.355493
#
# [924 rows x 8 columns]

# %% [markdown]
# CEK DATA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 924 entries, 0 to 923
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  924 non-null    int64
#  1   Address     924 non-null    object
#  2   Zip         924 non-null    object
#  3   Price       920 non-null    float64
#  4   Area        924 non-null    int64
#  5   Room        924 non-null    int64
#  6   Lon         924 non-null    float64
#  7   Lat         924 non-null    float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 57.9+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0         Price        Area        Room         Lon  \
# count  924.000000  9.200000e+02  924.000000  924.000000  924.000000
# mean   462.500000  6.220654e+05   95.952381    3.571429    4.888605
# std    266.880123  5.389942e+05   57.447436    1.592332    0.053140
# min      1.000000  1.750000e+05   21.000000    1.000000    4.644819
# 25%    231.750000  3.500000e+05   60.750000    3.000000    4.855834
# 50%    462.500000  4.670000e+05   83.000000    3.000000    4.886818
# 75%    693.250000  7.000000e+05  113.000000    4.000000    4.922337
# max    924.000000  5.950000e+06  623.000000   14.000000    5.029122
#
#               Lat
# count  924.000000
# mean    52.363326
# std      0.024028
# min     52.291519
# 25%     52.352077
# 50%     52.364631
# 75%     52.377598
# max     52.423805

# %%
print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}")
print(f"Duplicates: {df.duplicated().sum()}") 
print(f"missing data: {sum(df.isna().sum())}")
# Out:
# Rows: 924, Columns: 8
# Duplicates: 0
# missing data: 4

# %% [markdown]
# DATA PREPROCESSING AND DATA CLEANING

# %% [markdown]
# DROP MISSING VALUES

# %%
kolom=len(df.columns)
for i in range (0, kolom):
  df=df[df.iloc[:,i]!='?']
  df=df[df.iloc[:,i]!='']
  df=df[~df.iloc[:,i].isna()]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 920 entries, 0 to 923
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  920 non-null    int64
#  1   Address     920 non-null    object
#  2   Zip         920 non-null    object
#  3   Price       920 non-null    float64
#  4   Area        920 non-null    int64
#  5   Room        920 non-null    int64
#  6   Lon         920 non-null    float64
#  7   Lat         920 non-null    float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 64.7+ KB

# %%
df.drop_duplicates(keep= 'first',inplace = True) #menghapus data duplikat

# %%
print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}")
print(f"Duplicates: {df.duplicated().sum()}") 
print(f"missing data: {sum(df.isna().sum())}")
# Out:
# Rows: 920, Columns: 8
# Duplicates: 0
# missing data: 0

# %%
df = df.rename(columns={'Unnamed: 0': 'ID'})
df
# Out:
#       ID                                 Address      Zip     Price  Area  \
# 0      1            Blasiusstraat 8 2, Amsterdam  1091 CR  685000.0    64
# 1      2  Kromme Leimuidenstraat 13 H, Amsterdam  1059 EL  475000.0    60
# 2      3              Zaaiersweg 11 A, Amsterdam  1097 SM  850000.0   109
# 3      4            Tenerifestraat 40, Amsterdam  1060 TH  580000.0   128
# 4      5              Winterjanpad 21, Amsterdam  1036 KN  720000.0   138
# ..   ...                                     ...      ...       ...   ...
# 919  920                     Ringdijk, Amsterdam  1097 AE  750000.0   117
# 920  921         Kleine Beerstraat 31, Amsterdam  1033 CP  350000.0    72
# 921  922       Stuyvesantstraat 33 II, Amsterdam  1058 AK  350000.0    51
# 922  923   John Blankensteinstraat 51, Amsterdam  1095 MB  599000.0   113
# 923  924      S. F. van Ossstraat 334, Amsterdam  1068 JS  300000.0    79
#
#      Room       Lon        Lat
# 0       3  4.907736  52.356157
# 1       3  4.850476  52.348586
# 2       4  4.944774  52.343782
# 3       6  4.789928  52.343712
# 4       5  4.902503  52.410538
# ..    ...       ...        ...
# 919     1  4.927757  52.354173
# 920     3  4.890612  52.414587
# 921     3  4.856935  52.363256
# 922     4  4.965731  52.375268
# 923     4  4.810678  52.355493
#
# [920 rows x 8 columns]

# %% [markdown]
# LOCATION CHECK

# %%
import folium
map = folium.Map(location=[df.Lat.mean(), df.Lon.mean()], zoom_start=14, control_scale=True)
for index, location_info in df.iterrows():
    folium.Marker([location_info["Lat"], location_info["Lon"]], popup=location_info["Address"]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9378c1826b5ef85b88efd808982543a2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9378c1826b5ef85b88efd808982543a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9378c1826b5ef85b88efd808982543a2 = L.map(
#                 &quot;map_9378c1826b5ef85b88efd808982543a2&quot;,
#                 {
#                     center: [52.363271458425636, 4.8886521308078175],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_9378c1826b5ef85b88efd808982543a2);
#
#
#
#
#
#             var tile_layer_49e481254d6fa46bf68635721ccb49a2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9378c1826b5ef85b88efd808982543a2);
#
#
#             var marker_8da6b064853a7c5e82729844f1d38d06 = L.marker(
#                 [52.356157, 4.907736],
#                 {}
#             ).addTo(map_9378c1826b5ef85b88efd808982543a2);
#
#
#         var popup_e88513efdbea9011adb6ca9ce3878c23 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6661b13546af2719c80526d0c3ef36b1 = $(`&lt;div id=&quot;html_6661b13546af2719c80526d0c3ef36b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Blasiusstraat 8 2, Amsterdam&lt;/div&gt;`)[0];
#                 popup_e88513efdbea9011adb6ca9ce3878c23.setContent(html_6661b13546af2719c80526d0c3ef36b1);
#
#
#
#         marker_8da6b064853a7c5e82729844f1d38d06.bindPopup(popup_e88513efdbea9011adb6ca9ce3878c23)
#         ;
#
#
#
#
#             var marker_c3345457af2ffc12de4740ae0db10319 = L.marker(
#                 [52.348586, 4.850476],
#                 {}
#             ).addTo(map_9378c1826b5ef85b88efd808982543a2);
#
#
#         var popup_b7e34a08fdd58f5f368e4bc225aa180a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_19e28136f405e9e6b0662e582e3a02dd = $(`&lt;div id=&quot;html_19e28136f405e9e6b0662e582e3a02dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kromme Leimuidenstraat 13 H, Amsterdam&lt;/div&gt;`)[0];
#                 popup_b7e34a08fdd58f5f368e4bc225aa180a.setContent(html_19e28136f405e9e6b0662e582e3a02dd);
#
#
#
#         marker_c3345457af2ffc12de4740ae0db10319.bindPopup(popup_b7e34a08fdd58f5f368e4bc225aa180a)
#         ;
#
#
#
#
#             var marker_1f4ae40f44682b60c480e3fa1e7ba238 = L.marker(
#                 [52.343782, 4.944774],
#                 {}
#             ).addTo(map_9378c1826b5ef85b88efd808982543a2);
#
#
#         var popup_1f664d824149c6395a801d0c5c070b7c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_785fa51d45a14c11ae1c25214c898b5e = $(`&lt;div id=&quot;html_785fa51d45a14c11ae1c25214c898b5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Zaaiersweg 11 A, Amsterdam&lt;/div&gt;`)[0];
#                 popup_1f664d824149c6395a801d0c5c070b7c.setContent(html_785fa51d45a14c11ae1c25214c898b5e);
#
#
#
#         marker_1f4ae40f44682b60c480e3fa1e7ba238.bindPopup(popup_1f664d824149c6395a801d0c5c070b7c)
#         ;
#
#
#
#
#             var marker_b7c913051a3d9fc31bc1a16424b6edb4 = L.marker(
#                 [52.343712, 4.789928],
#                 {}
#             ).addTo(map_9378c1826b5ef85b88efd808982543a2);
#
#
#         var popup_89d25824e51ff582d0ab3a491805be45 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e166a033faf18bf68e39fa4baf677048 = $(`&lt;div id=&quot;html_e166a033faf18bf68e39fa4baf677048&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tenerifestraat 40, Amsterdam&lt;/div&gt;`)[0];
#                 popup_89d25824e51ff582d0ab3a491805be45.setContent(html_e166a033faf18bf68e39fa4baf677048);
#
#
#
#         marker_b7c913051a3d9fc31bc1a16424b6edb4.bindPopup(popup_89d25824e51ff582d0ab3a491805be45)
#         ;
#
#
#
#
#             var marker_3a1abbd784ff681dad21a98126ef0c31 = L.marker(
#                 [52.410538, 4.902503],
#                 {}
#             ).addTo(map_9378c1826b5ef85b88efd808982543a2);
#
#
#         var popup_3ab300747b7c8c36dd8756a0ee61bafa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4c24800150fd666711b3b7ca678b1b9d = $(`&lt;div id=&quot;html_4c24800150fd666711b3b7ca678b1b9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Winterjanpad 21, Amsterdam&lt;/div&gt;`)[0];
#                 popup_3ab300747b7c8c36dd8756a0ee61bafa.setContent(html_4c24800150fd666711b3b7ca678b1b9d);
#
#
#
#         marker_3a1abbd784ff681dad21a98126ef0c31.bindPopup(popup_3ab300747b7c8c36dd8

# %%
df['Price'] = df['Price'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 920 entries, 0 to 923
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       920 non-null    int64
#  1   Address  920 non-null    object
#  2   Zip      920 non-null    object
#  3   Price    920 non-null    int32
#  4   Area     920 non-null    int64
#  5   Room     920 non-null    int64
#  6   Lon      920 non-null    float64
#  7   Lat      920 non-null    float64
# dtypes: float64(2), int32(1), int64(3), object(2)
# memory usage: 61.1+ KB

# %%
df
# Out:
#       ID                                 Address      Zip   Price  Area  Room  \
# 0      1            Blasiusstraat 8 2, Amsterdam  1091 CR  685000    64     3
# 1      2  Kromme Leimuidenstraat 13 H, Amsterdam  1059 EL  475000    60     3
# 2      3              Zaaiersweg 11 A, Amsterdam  1097 SM  850000   109     4
# 3      4            Tenerifestraat 40, Amsterdam  1060 TH  580000   128     6
# 4      5              Winterjanpad 21, Amsterdam  1036 KN  720000   138     5
# ..   ...                                     ...      ...     ...   ...   ...
# 919  920                     Ringdijk, Amsterdam  1097 AE  750000   117     1
# 920  921         Kleine Beerstraat 31, Amsterdam  1033 CP  350000    72     3
# 921  922       Stuyvesantstraat 33 II, Amsterdam  1058 AK  350000    51     3
# 922  923   John Blankensteinstraat 51, Amsterdam  1095 MB  599000   113     4
# 923  924      S. F. van Ossstraat 334, Amsterdam  1068 JS  300000    79     4
#
#           Lon        Lat
# 0    4.907736  52.356157
# 1    4.850476  52.348586
# 2    4.944774  52.343782
# 3    4.789928  52.343712
# 4    4.902503  52.410538
# ..        ...        ...
# 919  4.927757  52.354173
# 920  4.890612  52.414587
# 921  4.856935  52.363256
# 922  4.965731  52.375268
# 923  4.810678  52.355493
#
# [920 rows x 8 columns]

# %%
sns.displot ( x = 'Room', kde = True, data = df)
plt.title("Distribusi Room")

sns.displot ( x = 'Area', kde = True, data = df)
plt.title("Distribusi Area")
plt.show()
# Out:
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\DEDEN\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
